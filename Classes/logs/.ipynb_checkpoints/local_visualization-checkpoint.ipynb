# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('2024-10-14-17-17-17/Kaggle/_0/balance=0.1/0/k-4/u-6/fraudulent/reward-probability/file.csv')

# %%
plt.plot(df)
